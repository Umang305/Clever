# %% [markdown]
# <a href="https://colab.research.google.com/github/Umang305/Clever/blob/master/Enablement_and_Engagement_of_Parents_at_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Enablement and Engagement of Parents at Work**

# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv("/content/drive/MyDrive/ctrl-del-hack-dataset/Train.csv")

# %%
train_data.head(20)
# Out:
#     Employee ID WFH Setup Available  ... Health Conditions               Support
# 0         17052                  No  ...               Yes                Leaves
# 1          9196                 Yes  ...                No                Career
# 2         25566                  No  ...               Yes  Caregiving Programme
# 3            84                  No  ...                No                Career
# 4         10929                 Yes  ...                No                Career
# 5         21627                 Yes  ...                No                Career
# 6          8050                 Yes  ...               Yes             Ergonomic
# 7          2733                  No  ...                No                Others
# 8           171                 Yes  ...               Yes                Others
# 9         26129                 Yes  ...                No                Leaves
# 10        20202                  No  ...               Yes                Leaves
# ...
